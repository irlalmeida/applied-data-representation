# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

info_db = pd.read_excel("/home/isabela.almeida/Documents/Lista 2 A2021 - casa_dados_internet.xlsx")

# %%
info_db.head(5)
info_db['Homem'].value_counts()
# Out:
# Concorda fortemente    358
# Concorda               234
# Discorda               118
# Discorda fortemente     65
# Name: Homem, dtype: int64

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
levels = info_db['Mulher'].unique()
values = [276, 268, 216, 65]
ax.bar(levels, values)
ax.set_ylabel('N° de mulheres')
ax.set_title('Eu não gosto de fornecer o número de meu cartão de crédito ou informações pessoais on-line')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
levels = ['Concorda fortemente','Concorda','Discorda ','Discorda fortemente']
values = [358, 234, 118, 65]
ax.bar(levels, values)
ax.set_ylabel('N° de homens')
ax.set_title('Eu não gosto de fornecer o número de meu cartão de crédito ou informações pessoais on-line')
plt.show()

# %%
data = [[276, 268, 216, 65],
[358, 234, 118, 65]]
X = np.arange(4)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(X + 0.00, data[0], color = 'b', width = 0.25)
ax.bar(X + 0.25, data[1], color = 'g', width = 0.25)
ax.legend(labels=['Mulheres', 'Homens'])
ax.set_xticks(X,('Concorda fortemente','Concorda','Discorda ','Discorda fortemente'))
